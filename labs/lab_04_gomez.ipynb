# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281_2022/blob/main/labs/lab_04/lab_04.ipynb
# " target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°04

# %% [markdown]
# ## Problema 01
#
# <img src="http://nelsoncos.com/wp-content/uploads/2017/02/sales-icon.png" width="360" height="360" align="center"/>
#
#
# EL conjunto de datos se denomina `company_sales_data.csv`, el cual contiene información tal como: número del mes, unidades, precio, etc.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(10,8)})

# %%
# cargar datos
df = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281_2022/main/labs/lab_04/data/company_sales_data.csv")
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# El objetivo es tratar de obtener la mayor información posible de este conjunto de datos. Para cumplir este objetivo debe resolver las siguientes problemáticas:
#
# **Observación.-** Puedes ocupar las librerías de Matplolib o Seaborn.

# %% [markdown]
# 1. Lea el "total_profit" de todos los meses, muéstrelo usando un gráfico lineal y un gráfico de dispersión.

# %%
#grafico lineal
plt.figure(figsize=(10, 6))
sns.lineplot(
    x='month_number',
    y='total_profit',
    data=df, color='Green'
)   
plt.show()
#Grafico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='month_number',
    y='total_profit',
    data=df, color='Green'
)   
plt.show()

# %% [markdown]
# 2. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico multilínea.

# %%
#elimino las columnas que no correspondan a datos de venta de productos y grafico
sns.lineplot(data=df.drop(['month_number', 'total_units', 'total_profit'], axis=1))

# %% [markdown]
# 3. Lea los datos de ventas de productos de "facecream" y "facewash" y muéstrelos usando el gráfico de barras.

# %%
#eje y
plt.bar(df['month_number'], df['facewash'], 0.6, label='facewash')
plt.bar(df['month_number'] + 0.2, df['facecream'], 0.35, label='facecream')
# eje x
plt.xticks(df['month_number'], df['month_number'])
#nombres de los ejes
plt.legend(loc='best')
plt.ylabel('Ventas')
plt.xlabel('Meses')
plt.show()

# %% [markdown]
# 4. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico box-plot.

# %%
#elimino lo que no es de ventas de producto y se grafica lo demas
df2 = df.drop(['month_number', 'total_units', 'total_profit'], axis=1)
plt.figure(figsize=(10, 6))
sns.boxplot(data=df2)
plt.show()

# %% [markdown]
# 5. Calcule los datos de ventas totales del año pasado para cada producto y muéstrelos usando un gráfico circular

# %%
suma=df.sum() #suma hacia abajo
s=[suma[1],suma[2],suma[3],suma[4],suma[5],suma[6]]
colors = sns.color_palette('Set2')[1:6]
labels = ['facewash','facecream','toothpaste','bathingsoap','shampoo','moisturizer']
plt.pie(s, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
suma
# Out:
# month_number         78
# facecream         34480
# facewash          18515
# toothpaste        69910
# bathingsoap      114010
# shampoo           25410
# moisturizer       18515
# total_units      312330
# total_profit    3123300
# dtype: int64
